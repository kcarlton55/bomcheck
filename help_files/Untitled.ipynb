# %%
import flashcardz as fc

# %%
c()
# Out:
#   0. resollar vi     (t: 7)     6. telonero, -nera (t: 5)    12. batidora nf     (t: 1)    18. enlace nm       (t: 0)
#   1. bisoño adj      (t: 9)     7. fomentar vtr    (t: 3)    13. enchufe SM      (t: 1)    19. cajero automáti (t: 0)
#   2. genio nm        (t: 7)     8. alentar vtr     (t: 4)    14. cari nm         (t: 1)    20. camioneta nf    (t: 0)
#   3. niñera SF       (t: 7)     9. cuento nm       (t: 2)    15. cotillear vi    (t: 1)    21. esmerarse v prn (t: 0)
#   4. pila nf         (t: 6)    10. picudo rojo     (t: 2)    16. fisgonear vtr   (t: 1)    22. cabezota adj mf (t: 0)
#   5. escozor nm      (t: 4)    11. gruñón, gruñóna (t: 2)    17. forro nm        (t: 0)

# %%
fc.add('cabezota adj mf',
'''
ES: coloquial (terco, testarudo)    pig-headed adj
                                    obstinate adj
                                    stubborn adj
 	Mi marido es un hombre cabezota, pero también es muy tierno.
 	My husband is pig-headed, but he's also very tender.
    
Per Dexter 1x02, 34:16: <u>head strong<>    
    
    
    ''')
# Out:
# cabezota adj mf
#
# ES: coloquial (terco, testarudo)    pig-headed adj
#                                     obstinate adj
#                                     stubborn adj
#  	Mi marido es un hombre cabezota, pero también es muy tierno.
#  	My husband is pig-headed, but he's also very tender.
#
# Per Dexter 1x02, 34:16: head strong
#
#
#
# Number of cards now at:  23
